# %% [markdown]
# <a href="https://colab.research.google.com/github/Jona1949713/RedesNeuralesActividades_1949713/blob/main/AF3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# AF3 Entrenamiento de Red Neuronal Artificial simple
# Alumnos:
# Jonathan Raziel Treviño Cruz 1949713 y
# Carlos Emilio Orozco Ibarra 1905750

# %%
# TensorFlow y tf.keras
import tensorflow as tf
from tensorflow import keras

# Librerias de ayuda
import numpy as np
import matplotlib.pyplot as plt

# %%
letras_mnist = keras.datasets.mnist

# %%
#Normalización
(train_images, train_labels), (test_images, test_labels) =letras_mnist.load_data()

train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
class_names = ['cero', 'uno', 'dos', 'tres' ,'cuatro' ,'cinco','seis','siete', 'ocho',  'nueve']
train_images.shape
len(train_labels)
train_labels
test_images.shape
len(test_labels)
#Rango de la gama de color que llega hasta 255
train_images = train_images / 255.0

test_images = test_images / 255.0

# %%
#Muestra de 25 números para que los relacione con su nombre
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
#Construir un modelo para poder configurar las capas 
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
#Aqui ya se empieza a entrenar a la red
model.fit(train_images, train_labels, epochs=8)
# Out:
# Epoch 1/8
# 1875/1875 [==============================] - 8s 4ms/step - loss: 2.3013 - accuracy: 0.1124
# Epoch 2/8
# 1875/1875 [==============================] - 7s 4ms/step - loss: 2.3013 - accuracy: 0.1124
# Epoch 3/8
# 1875/1875 [==============================] - 8s 4ms/step - loss: 2.3013 - accuracy: 0.1124
# Epoch 4/8
# 1875/1875 [==============================] - 8s 4ms/step - loss: 2.3013 - accuracy: 0.1124
# Epoch 5/8
# 1875/1875 [==============================] - 7s 4ms/step - loss: 2.3013 - accuracy: 0.1124
# Epoch 6/8
# 1875/1875 [==============================] - 8s 4ms/step - loss: 2.3014 - accuracy: 0.1124
# Epoch 7/8
# 1875/1875 [==============================] - 7s 4ms/step - loss: 2.3014 - accuracy: 0.1124
# Epoch 8/8
# 1875/1875 [==============================] - 8s 4ms/step - loss: 2.3014 - accuracy: 0.1124

# %%
#Aqui podemos ver que tenemos una precision del 73% 
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 2.3011 - accuracy: 0.1135 - 509ms/epoch - 2ms/step
#
# Test accuracy: 0.11349999904632568

# %%
predictions = model.predict(test_images)
predictions[12]
np.argmax(predictions[12])
# Out:
# 313/313 [==============================] - 1s 2ms/step
# 1

# %%
test_labels[12]
# Out:
# 9

# %%
#Se le dice a la red que haga una predicción para ver el entrenamiento previo en acción
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
#Ejemplo 
i = 12
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %%
# Aquí se muestran algunas pruebas del aprendizaje de nuestra red, según el análisis que hicimos,
#debe tener una exactitud del 73%
# El color azul es la predicción correcta mientras que la de color rojo es la incorrecta
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], test_labels)
plt.tight_layout()
plt.show()

# %%
#Prueba para una sola imagen

# %%
img=test_images[1]
print(img.shape)
# Out:
# (28, 28)

# %%
img=(np.expand_dims(img,0))
print(img.shape)
# Out:
# (1, 28, 28)

# %%
predictions_single=model.predict(img)
print(predictions_single)
# Out:
# 1/1 [==============================] - 0s 39ms/step
# [[0.09908158 0.11365199 0.09872067 0.10095853 0.09707025 0.0904928
#   0.09938388 0.10542087 0.09700093 0.09821856]]

# %%
plot_value_array(1, predictions_single[0], test_labels)
_=plt.xticks(range(10), class_names, rotation=45)

# %%
np.argmax(predictions_single[0])
# Out:
# 1
